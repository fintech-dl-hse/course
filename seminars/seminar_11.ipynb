# %% [markdown]
# ## Методы сжатия (ускорения) моделей
#
# * структурный прунинг
# * дистилляция знаний
# * квантизация весов

# %% [markdown]
# ## The Story of Heads
#
#
# * [Blog](https://lena-voita.github.io/posts/acl19_heads.html)
# * [Paper](https://aclanthology.org/P19-1580.pdf)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Encoder Self-Attention
#
# <img src='https://raw.githubusercontent.com/mrsndmn/fairseq/hcg_pruning/l1.5_encoder_attention_p_open.gif' />

# %% [markdown]
# #### Encoder-Decoder Attention
#
# <img src='https://raw.githubusercontent.com/mrsndmn/fairseq/hcg_pruning/l1.5_decoder_encoder_attention_p_open.gif' />

# %% [markdown]
# ### Decoder Self-Attention
#
# <img src='https://raw.githubusercontent.com/mrsndmn/fairseq/hcg_pruning/l1.5_decoder_self_attention_p_open.gif' />

# %% [markdown]
# ## Nonautoregressive transformers
#
# https://arxiv.org/abs/2012.15833

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Проблема
#
# `N` раз запускаем декодер для того, чтобы сгенерить последовательность длинны `N`.
#
#
# Можно гененрировать целевую последовательность сразу независимо, параллельно

# %% [markdown]
# ### Nonautiregresive models
#
# * iterative refinement
# * fully non autoregressive

# %% [markdown]
# ### Autoregressive transformers speedup

# %% [markdown]
# **Deep Encoder Shallow Decoder** [paper](https://arxiv.org/abs/2006.10369)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Transformers again

# %% [markdown]
# ## Translation
#
#
# [Notebook](https://colab.research.google.com/drive/1D-g3fH8pAelBgJMJWDqVJmvQhGfT_qRH?usp=sharing)
#
#
# ### transformers/notebooks
#
# https://huggingface.co/docs/transformers/notebooks

# %% [markdown]
# # Lecture Models
#
# * [gpt2](https://huggingface.co/gpt2)
# * [bert-base-uncased](https://huggingface.co/bert-base-uncased) /
#  [bert-base-cased](https://huggingface.co/bert-base-cased)
# * [roberta-base](https://huggingface.co/roberta-base)
# * [bart-base](https://huggingface.co/facebook/bart-base)
# * [t5-base](https://huggingface.co/t5-base)
